# %% [markdown]
# # Hola Cientificos

# %%
import random

# %%
def generar_matriz(N):
    matriz= []
    for i in range (N):
        fila = []
        for j in range(N):
            fila.append(random.randint(1, 9))
        matriz.append(fila)
    return matriz

N = 5

matriz_aleatoria = generar_matriz(N)
for fila in matriz_aleatoria:
    print(fila)

def imprimir_matriz(matriz):
    for fila in matriz:
        fila_formateada = ' '.join(f'{elemento:2}' for elemento in fila)
        print(fila_formateada)
# Out:
# [9, 5, 2, 2, 5]
# [8, 1, 7, 5, 1]
# [3, 3, 4, 5, 9]
# [9, 5, 8, 7, 3]
# [5, 2, 6, 4, 6]

# %%
print("Matriz de 5x5")
m_5 = generar_matriz(5)
imprimir_matriz(m_5)
print("============")
print("Matriz de 10x10")
m_10 = generar_matriz(10)
imprimir_matriz(m_10)
print("============")
print("Matriz de 20x20")
m_20 = generar_matriz(20)
imprimir_matriz(m_20)
# Out:
# Matriz de 5x5
#  3  7  5  6  5
#  3  5  7  3  3
#  5  4  7  7  1
#  1  7  6  5  6
#  3  1  5  6  5
# ============
# Matriz de 10x10
#  3  2  4  8  9  5  3  8  3  3
#  5  5  9  6  8  8  1  6  3  3
#  8  2  7  5  6  1  8  3  7  1
#  6  2  6  8  6  8  4  3  5  3
#  9  3  6  2  9  6  6  5  3  3
#  3  2  6  9  8  3  1  3  3  7
#  6  8  1  4  5  6  3  5  6  8
#  8  9  3  4  4  4  3  6  4  9
#  5  6  1  7  9  8  2  5  1  7
#  7  9  3  9  3  6  8  9  8  6
# ============
# Matriz de 20x20
#  6  5  2  6  2  7  8  8  2  2  1  3  8  8  3  3  1  7  1  9
#  3  7  7  3  2  2  9  7  5  7  2  4  7  5  8  1  9  5  3  9
#  2  2  5  7  6  7  4  2  6  4  5  6  5  2  5  2  5  4  6  2
#  5  6  6  8  8  1  1  5  8  6  4  4  8  9  1  6  1  9  2  6
#  4  7  2  4  4  2  1  3  4  1  4  6  4  2  2  3  3  7  1  5
#  9  8  7  4  6  2  2  5  1  8  8  3  3  9  6  7  1  9  7  2
#  1  3  6  9  6  4  6  7  1  4  7  9  3  4  5  3  1  1  4  9
#  2  8  3  6  2  6  2  1  8  7  4  3  7  3  9  9  3  1  1  3
#  4  6  7  5  3  3  7  2  2  5  4  4  4  1  4  2  3  6  3  6
#  8  3  1  3  8  5  4  2  4  5  6  9  1  5  9  1  3  1  5  7
#  7  9  1  3  1  8  8  3  8  8  6  5  5  5  6  5  1  2  2  2
#  3  6  7  8  8  5  8  8  8  6  9  5  6  1  7  9  7  8  1  5
#  9  4  8  6  1  4  8  3  1  9  4  9  1  3  3  5  6  9  2  2
#  6  3  1  8  1  6  3  3  1  6  2  4  6  7  9  6  6  7  5  2
#  2  3  5  2  9  1  5  1  3  9  5  8  6  2  5  7  4  9  3  5
#  1  6  2  2  9  5  7  6  4  5  8  3  5  7  7  5  7  5  2  9
#  3  8  3  6  4  7  9  2  4  9  5  1  5  3  3  2  8  7  5  6
#  7  3  1  3  6  4  6  7  4  2  1  1  8  4  5  1  8  1  4  1
#  7  2  6  5  5  3  3  4  7  1  9  6  2  3  9  9  4  4  9  6
#  9  2  7  6  5  7  7  2  8  3  3  3  6  8  8  6  1  6  1  4
